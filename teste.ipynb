# %%
import numpy as np

# %%
tamanho = [3,20,1]

# %%
teste = [np.random.randn(y, 1) for y in tamanho[1:]]
teste
# Out:
# [array([[ 1.0264642 ],
#         [-2.3498893 ],
#         [ 0.20417118],
#         [ 1.09217795],
#         [ 0.57229689],
#         [ 2.08490892],
#         [-0.1769407 ],
#         [ 1.51527138],
#         [ 0.81655813],
#         [-0.05843746],
#         [ 0.48189913],
#         [-0.07321903],
#         [-2.08443501],
#         [-0.21697127],
#         [-0.69797866],
#         [ 1.30185927],
#         [ 1.34055707],
#         [ 2.06454441],
#         [ 0.24007372],
#         [ 1.32656137]]),
#  array([[1.83485073]])]

# %%
[np.random.randn(y, x) for x, y in zip(tamanho[:-1], tamanho[1:])]
# Out:
# [array([[ 0.32690912,  0.40870902,  0.1984645 ],
#         [ 0.33225251,  0.51631542,  1.01130266],
#         [-0.9949291 , -0.94579982, -0.40003511],
#         [-0.3195215 , -0.00355465,  0.94326402],
#         [ 1.30618059, -0.15211547,  0.11529657],
#         [-1.05640684,  1.19835248,  0.76974448],
#         [ 2.08995553, -0.95760464,  0.29300567],
#         [-1.35913852, -0.65028951,  0.77290551],
#         [-0.5056908 ,  0.90383658,  0.73115272],
#         [ 1.0084781 , -0.9162418 ,  0.67146005],
#         [ 0.71920552, -0.17479769, -2.28417271],
#         [-0.22773155,  0.21322976,  0.26699577],
#         [-0.27830753,  1.96284424,  1.1449936 ],
#         [ 0.649291  ,  1.26866599, -0.1261434 ],
#         [ 0.86144914,  1.12997743, -0.12795822],
#         [ 0.32863649,  0.23696016,  0.89779002],
#         [-1.18181106, -0.96456214, -0.62760627],
#         [-1.20943332,  0.4072167 ,  0.77826116],
#         [-0.26400953,  1.15235951, -0.18093798],
# ...
